# %%
import pandas as pd
import numpy as np
from pathlib import Path

import plotly.express as px
pd.options.plotting.backend = 'plotly'

# %%
recipes = pd.read_csv("RAW_recipes.csv")
ratings = pd.read_csv("RAW_interactions.csv")

# %%
ratings
# Out:
#             user_id  recipe_id        date  rating  \
# 0             38094      40893  2003-02-17       4
# 1           1293707      40893  2011-12-21       5
# 2              8937      44394  2002-12-01       4
# 3            126440      85009  2010-02-27       5
# 4             57222      85009  2011-10-01       5
# ...             ...        ...         ...     ...
# 1132362      116593      72730  2003-12-09       0
# 1132363      583662     386618  2009-09-29       5
# 1132364      157126      78003  2008-06-23       5
# 1132365       53932      78003  2009-01-11       4
# 1132366  2001868099      78003  2017-12-18       5
#
#                                                     review
# 0        Great with a salad. Cooked on top of stove for...
# 1        So simple, so delicious! Great for chilly fall...
# 2        This worked very well and is EASY.  I used not...
# 3        I made the Mexican topping and took it to bunk...
# ...

# %%
# Merge dataframes
merged = recipes.merge(ratings, how="left", left_on="id", right_on="recipe_id")
merged['rating'] = merged['rating'].replace(0, np.nan)

# %%
merged
# Out:
#                                                  name      id  minutes  \
# 0          arriba   baked winter squash mexican style  137739       55
# 1          arriba   baked winter squash mexican style  137739       55
# 2          arriba   baked winter squash mexican style  137739       55
# 3                    a bit different  breakfast pizza   31490       30
# 4                    a bit different  breakfast pizza   31490       30
# ...                                               ...     ...      ...
# 1132362                     zydeco ya ya deviled eggs  308080       40
# 1132363        cookies by design   cookies on a stick  298512       29
# 1132364  cookies by design   sugar shortbread cookies  298509       20
# 1132365  cookies by design   sugar shortbread cookies  298509       20
# 1132366  cookies by design   sugar shortbread cookies  298509       20
#
#          contributor_id   submitted  \
# 0                 47892  2005-09-16
# 1                 47892  2005-09-16
# ...

# %%
# Find average rating per recipe and add to recipes dataframe
avg_ratings = merged.groupby('id')['rating'].mean()
avg_ratings_df = avg_ratings.reset_index().rename(columns={'rating': 'avg_rating'})

recipes = recipes.merge(avg_ratings_df, how='left', on='id')

# %%
# Finding columns with missing vals
nan_columns = recipes.columns[recipes.isnull().any()]

print(nan_columns)
# Out:
# Index(['name', 'description', 'avg_rating'], dtype='object')

# %%
# Fill missing descriptions with a placeholder
recipes['description'] = recipes['description'].fillna('No description available')

print(f"Number of missing descriptions after filling: {recipes['description'].isna().sum()}")
# Out:
# Number of missing descriptions after filling: 0

# %%
# Check for missing columns
nan_columns = recipes.columns[recipes.isnull().any()]

print(nan_columns)
# Out:
# Index(['name', 'avg_rating'], dtype='object')

# %%
# Check missing values in Average Rating
recipes[recipes['avg_rating'].isna()]
# Out:
#                                                   name      id  minutes  \
# 63                   more  more    apple pear jigglers   63593      125
# 64          mr  grant you took half veal prince orloff   43164      120
# 74                               philly  waldorf salad    5060       60
# 109     zupa ze swiezych grzybow  polish mushroom soup  105069       40
# 138                                      lplermagronen  455351       55
# ...                                                ...     ...      ...
# 231537                              zucchini oat bread  292835      105
# 231580                      zuppa de clams  or mussels   88280       40
# 231591                                   zuppa inglese   26261      120
# 231607           zurichgeschnetzeltes or diced chicken   16940       11
# 231628                              zydeco green beans  185979       20
#
#         contributor_id   submitted  \
# 63               47858  2003-06-02
# ...

# %% [markdown]
# We would try to fill in missingness here, but these recipes have no ratings, and such cannot be predicted.

# %%
# Convert nutrition column from string to list
recipes['nutrition'] = recipes['nutrition'].apply(eval)

# %%
# Convert nutrition list into separate columns
nutrition_df = pd.DataFrame(recipes['nutrition'].tolist(), 
                          columns=['calories', 'total fat (PDV)', 'sugar (PDV)', 'sodium (PDV)', 'protein (PDV)', 'saturated fat (PDV)', 'carbohydrates (PDV)'])

# Add the nutrition columns to the original dataframe
recipes = pd.concat([recipes, nutrition_df], axis=1)

# %%
recipes
# Out:
#                                                 name      id  minutes  \
# 0         arriba   baked winter squash mexican style  137739       55
# 1                   a bit different  breakfast pizza   31490       30
# 2                          all in the kitchen  chili  112140      130
# 3                                 alouette  potatoes   59389       45
# 4                 amish  tomato ketchup  for canning   44061      190
# ...                                              ...     ...      ...
# 231632                                   zydeco soup  486161       60
# 231633                              zydeco spice mix  493372        5
# 231634                     zydeco ya ya deviled eggs  308080       40
# 231635        cookies by design   cookies on a stick  298512       29
# 231636  cookies by design   sugar shortbread cookies  298509       20
#
#         contributor_id   submitted  \
# 0                47892  2005-09-16
# 1                26278  2002-06-17
# ...

# %%
# Convert times to time series
recipes['submitted'] = pd.to_datetime(recipes['submitted'])

# %%
# Head of cleaned dataframe
recipes.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id  submitted  \
# 0           47892 2005-09-16
# 1           26278 2002-06-17
# 2          196586 2005-02-25
# 3           68585 2003-04-14
# 4           41706 2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# ...

# %%
# Distribution of average ratings per recipe
fig = px.histogram(
    recipes,
    x='avg_rating',
    nbins=20,
    title='Distribution of Average Recipe Ratings',
    labels={'avg_rating': 'Average Rating'},
    template='plotly_white'
)
fig.update_layout(title_x=0.5)
fig.show()

# %%
# Distribution of preparation time for each recipe
fig = px.box(
    recipes[recipes['minutes'] <= 300], # removed extreme outliers
    y='minutes',
    title='Preparation Time Distribution',
    labels={'minutes': 'Preparation Time (minutes)'},
    template='plotly_white',
    color_discrete_sequence=['#EF553B']
)
fig.update_layout(title_x=0.5, width=500, height=800)
fig.show()

# %%
# Distribution of calories in recipes
fig = px.histogram(
    recipes[recipes['calories'] <= 3000], # removed outliers
    x='calories',
    nbins=30,
    title='Distribution of Calories in Recipes',
    labels={'calories': 'Calories'},
    template='plotly_white',
    color_discrete_sequence=['#FFA15A']
)
fig.update_layout(title_x=0.5)
fig.show()

# %%
# Distribution of protein in recipes
fig = px.histogram(
    recipes[(recipes['protein (PDV)'] <= 100)],  # focus on relevant bin range
    x='protein (PDV)',
    title='Distribution of Protein Values (PDV)',
    labels={'protein (PDV)': 'Protein (% Daily Value)'},
    template='plotly_white',
    color_discrete_sequence=['#00CC96']
)
fig.update_layout(title_x=0.5)
fig.show()

# %% [markdown]
# lets look at missingness

# %%
print("Average minutes for recipes with missing ratings:", recipes[recipes['avg_rating'].isna()]['minutes'].mean())
print("Average minutes for recipes with non-missing ratings:", recipes[recipes['avg_rating'].notna()]['minutes'].mean())
# Out:
# Average minutes for recipes with missing ratings: 287.32752129978206
# Average minutes for recipes with non-missing ratings: 9601.48664989629

# %%
recipes = recipes[recipes['minutes'] < 10000]

# %%
recipes
# Out:
#                                                 name      id  minutes  \
# 0         arriba   baked winter squash mexican style  137739       55
# 1                   a bit different  breakfast pizza   31490       30
# 2                          all in the kitchen  chili  112140      130
# 3                                 alouette  potatoes   59389       45
# 4                 amish  tomato ketchup  for canning   44061      190
# ...                                              ...     ...      ...
# 231632                                   zydeco soup  486161       60
# 231633                              zydeco spice mix  493372        5
# 231634                     zydeco ya ya deviled eggs  308080       40
# 231635        cookies by design   cookies on a stick  298512       29
# 231636  cookies by design   sugar shortbread cookies  298509       20
#
#         contributor_id  submitted  \
# 0                47892 2005-09-16
# 1                26278 2002-06-17
# ...

# %%
print("Average minutes for recipes with missing ratings:", recipes[recipes['avg_rating'].isna()]['minutes'].mean())
print("Average minutes for recipes with non-missing ratings:", recipes[recipes['avg_rating'].notna()]['minutes'].mean())
# Out:
# Average minutes for recipes with missing ratings: 104.81286084013537
# Average minutes for recipes with non-missing ratings: 80.20416431045452

# %% [markdown]
# # Prediction Problem
#
# Can we predict rating from user activity?
